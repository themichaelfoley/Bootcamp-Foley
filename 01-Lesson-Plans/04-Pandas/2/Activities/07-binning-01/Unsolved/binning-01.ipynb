# %% [markdown]
# # Categorizing Records in Pandas DataFrames

# %% [markdown]
# ## 1. Import Libraries and Dependencies

# %%
# import dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## 2. Set the File Path to the CSV using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
csvpath = Path("../Resources/cleaned_people_data.csv")

# %% [markdown]
# ## 3. Import the CSV into Pandas DataFrame

# %%
# Use the file path to read the CSV into a DataFrame and display a few rows
people_df = pd.read_csv(csvpath, index_col="Person_ID")
people_df.head()
# Out:
#              Last_Name First_Name  Gender  \
# Person_ID
# 1            Lenormand    Keriann  Female
# 2                Rupke    Huntley    Male
# 3          Dalgarnowch     Gorden    Male
# 4              Unnamed     Cullie    Male
# 5            Strangman      Ariel  Female
#
#                                                   University  \
# Person_ID
# 1                                          Aurora University
# 2                              Osaka University of Economics
# 3                                          Ludong University
# 4          Université des Sciences et de la Technologie d...
# 5                                     Boise State University
#
#                    Occupation   Salary                            Email  Age
# Person_ID
# 1          Nurse Practicioner  58135.0  klenormand0@businessinsider.com   27
# 2             Project Manager  96053.0              hrupke1@reuters.com   22
# 3          Environmental Tech  59196.0      gdalgarnowch2@microsoft.com   40
# 4             Legal Assistant  88493.0               cputten3@nymag.com   62
# 5             Project Manager  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ## 4. Create Bins for Total Ranking

# %%
# Create the variable bins to define our bounds for when we cut the dataframe.
bins = [0, 30000, 70000, 100000, 200000]
bin_names = ['Low', 'Moderate', 'Above Average', 'High']

# Create names for the bins

# %% [markdown]
# ## 5. Label Records According to the Corresponding Bin

# %%
# Add a column named "Salary Level" to people_df and slice the data into the bins
people_df["Salary Level"] = pd.cut(people_df["Salary"], bins, labels= bin_names)
people_df.tail(30)
# Out:
#               Last_Name  First_Name  Gender  \
# Person_ID
# 971            Perchard       Ennis    Male
# 972            Attfield      Sigrid  Female
# 973             Spurdle       Kathi  Female
# 974          Haspineall     Antonio    Male
# 975           Shoveller   Bernadina  Female
# 976             Pickett      Nanete  Female
# 977            Lethbrig      Hastie    Male
# 978         McPhillimey      Danice  Female
# 979           Yurchenko        Kale    Male
# 980               Eykel      Dillon    Male
# 981              Tarbox       Alley    Male
# 982           Cocksedge       Nydia  Female
# 983          Boutellier       Dayna  Female
# 984             Maharey       Angie  Female
# 985        Strongitharm      Felice    Male
# 986               Grint     Humbert    Male
# 987             Morratt        Kaye  Female
# 988           Karolczyk      Jillie  Female
# 989               Waker  Estrellita  Female
# 990             Unnamed       Urson    Male
# 991           Hampshire      Julian    Male
# 992             Glossop      Davine  Female
# 993                Rugg    Dorothea  Female
# 994           Griffitts     Damaris  Female
# 995              Jeacop        Iggy    Male
# 996            Crumpton        Meta  Female
# 997             Gilford       Gunar    Male
# 998             Gurling    Lucretia  Female
# 999                Yang      Andrew    Male
# 999                Yang      Andrew    Male
#
#                                                   University  \
# Person_ID
# 971                                     University of Exeter
# 972                                  Universidad de La Salle
# 973                             United States Sports Academy
# 974                                    Lansbridge University
# 975                              Midwestern State University
# 976        Ecole Nationale Supérieure de Physique de Gren...
# 977                                      Ecole Polytechnique
# 978                                      Université d'Artois
# 979                      Southeast Missouri State University
# 980                                          Shorter College
# 981                            University of Alaska (System)
# 982                                    University of Wroclaw
# 983                                         Ummah University
# 984                                    Utsunomiya University
# 985        University of Engineering and Technology Peshawar
# 986        National Technical University (Kharkiv Polytec...
# 987        Shaheed Zulifkar Ali Bhutto Institute of Scien...
# 988                                       Providence College
# 989                                      New England College
# 990                                   Wilberforce University
# 991                               Johnson & Wales University
# 992                      Université René Descartes (Paris V)
# 993                   Universidad Politécnica de El Salvador
# 994                                   The College of Wooster
# 995                                  University of Greenwich
# 996                     ECAM - Institut Supérieur Industriel
# 997                                        Smolny University
# 998                                Institut Teknologi Telkom
# 999                    Rutgers University School of Business
# 999                    Rutgers University School of Business
#
#                          Occupation    Salary  \
# Person_ID
# 971          Accounting Assistant I  109716.0
# 972         Senior Quality Engineer   93769.0
# 973                    VP Marketing   56669.0
# 974                 Legal Assistant   71608.0
# 975               Assistant Manager   63355.0
# 976         Human Resources Manager  108835.0
# 977             Electrical Engineer   73842.0
# 978        Automation Specialist II   71578.0
# 979              Biostatistician IV   54576.0
# 980                      Pharmacist  110623.0
# 981              Speech Pathologist   91118.0
# 982                Quality Engineer   63085.0
# 983             Software Engineer I   70141.0
# 984                    Accountant I   65560.0
# 985                         Actuary   60366.0
# 986               Financial Analyst  114068.0
# 987          Senior Sales Associate   82362.0
# 988                Dental Hygienist   52966.0
# 989        Database Administrator I   80118.0
# 990                       Librarian   79603.0
# 991               Chemical Engineer   79024.0
# 992              VP Quality Control   50599.0
# 993                    VP Marketing  114586.0
# 994                   Senior Editor  113339.0
# 995                 Sales Associate   82726.0
# 996                Registered Nurse   57060.0
# 997               Marketing Manager   76109.0
# 998           Software Engineer III   92115.0
# 999             Curriculum Engineer   60000.0
# 999             Curriculum Engineer   60000.0
#
#                                         Email  Age   Salary Level
# Person_ID
# 971                   eperchardqy@storify.com   64           High
# 972        sattfieldqz@nationalgeographic.com   42  Above Average
# 973                       kspurdler0@ucla.edu   48       Moderate
# 974          ahaspineallr1@simplemachines.org   33  Above Average
# 975                       bshovellerr2@ca.gov   33       Moderate
# 976               npickettr3@businesswire.com   61           High
# 977                     hlethbrigr4@europa.eu   32  Above Average
# 978                 dmcphillimeyr5@flickr.com   60  Above Average
# 979                 kyurchenkor6@netscape.com   54       Moderate
# 980                deykelr7@independent.co.uk   58           High
# 981                     atarboxr8@comcast.net   28  Above Average
# 982                       ncocksedger9@goo.gl   38       Moderate
# 983                  dboutellierra@tumblr.com   22  Above Average
# 984                         amahareyrb@w3.org   61       Moderate
# 985                    fstrongitharmrc@pen.io   43       Moderate
# 986                    hgrintrd@google.com.br   64           High
# 987                      kmorrattre@youku.com   53  Above Average
# 988                    jkarolczykrf@unblog.fr   26       Moderate
# 989                    ewakerrg@angelfire.com   59  Above Average
# 990                       uenrdigorh@gmpg.org   48  Above Average
# 991                   jhampshireri@disqus.com   26  Above Average
# 992                  dglossoprj@goodreads.com   47       Moderate
# 993                  druggrk@miitbeian.gov.cn   51           High
# 994                 dgriffittsrl@mapquest.com   42           High
# 995                     ijeacoprm@4shared.com   22  Above Average
# 996                        mcrumptonrn@qq.com   52       Moderate
# 997                      ggilfordro@yandex.ru   32  Above Average
# 998                          lgurlingrp@de.vu   48  Above Average
# 999                      ayang@codedrills.com   53       Moderate
# 999                      ayang@codedrills.com   53       Moderate

# %%
people_df.dtypes
# Out:
# Last_Name         object
# First_Name        object
# Gender            object
# University        object
# Occupation        object
# Salary           float64
# Email             object
# Age                int64
# Salary Level    category
# dtype: object
