# %% [markdown]
# # Grouping Data in Pandas DataFrames

# %% [markdown]
# ## 1. Import Libraries and Dependencies

# %%
# Import necessary libraries and dependencies
import pandas as pd
import numpy as np
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
clean_people = Path("../Resources/cleaned_people_data.csv")
people_df = pd.read_csv(clean_people, index_col="Person_ID")
people_df.head()
# Out:
#              Last_Name First_Name  Gender  \
# Person_ID
# 1            Lenormand    Keriann  Female
# 2                Rupke    Huntley    Male
# 3          Dalgarnowch     Gorden    Male
# 4              Unnamed     Cullie    Male
# 5            Strangman      Ariel  Female
#
#                                                   University  \
# Person_ID
# 1                                          Aurora University
# 2                              Osaka University of Economics
# 3                                          Ludong University
# 4          Université des Sciences et de la Technologie d...
# 5                                     Boise State University
#
#                    Occupation   Salary                            Email  Age
# Person_ID
# 1          Nurse Practicioner  58135.0  klenormand0@businessinsider.com   27
# 2             Project Manager  96053.0              hrupke1@reuters.com   22
# 3          Environmental Tech  59196.0      gdalgarnowch2@microsoft.com   40
# 4             Legal Assistant  88493.0               cputten3@nymag.com   62
# 5             Project Manager  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ## 3. Read the CSV into a Pandas DataFrame

# %%
# Use the file path to read the CSV into a DataFrame and display a few rows
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# 4  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ## 4. Group DataFrame by `Occupation` and perform `count` aggregation

# %%
# Group by `Occupation` and perform count
people_df.groupby("Occupation").count()
# Out:
#                             Last_Name  First_Name  Gender  University  Salary  \
# Occupation
# Account Coordinator                 6           6       6           6       6
# Account Executive                   4           4       4           4       4
# Account Representative I            1           1       1           1       1
# Account Representative II           5           5       5           5       5
# Account Representative III          4           4       4           4       4
# ...                               ...         ...     ...         ...     ...
# Web Designer III                    1           1       1           1       1
# Web Developer I                     2           2       2           2       2
# Web Developer II                    1           1       1           1       1
# Web Developer III                   3           3       3           3       3
# Web Developer IV                    4           4       4           4       4
#
#                             Email  Age
# Occupation
# Account Coordinator             6    6
# Account Executive               4    4
# Account Representative I        1    1
# Account Representative II       5    5
# Account Representative III      4    4
# ...                           ...  ...
# Web Designer III                1    1
# Web Developer I                 2    2
# Web Developer II                1    1
# Web Developer III               3    3
# Web Developer IV                4    4
#
# [183 rows x 7 columns]

# %% [markdown]
# ## 5. Group DataFrame by `Occupation` and Calculate Average Salary and Age

# %%
# Calculate average Salary and Age for each Occupation
people_df.groupby("Occupation").mean()
# Out:
#                                   Salary        Age
# Occupation
# Account Coordinator         91525.000000  52.666667
# Account Executive           79902.750000  47.750000
# Account Representative I    75871.000000  63.000000
# Account Representative II   72313.400000  41.600000
# Account Representative III  91499.750000  39.500000
# ...                                  ...        ...
# Web Designer III            78667.000000  30.000000
# Web Developer I             99438.500000  46.000000
# Web Developer II            75447.000000  58.000000
# Web Developer III           87014.666667  41.333333
# Web Developer IV            76815.250000  34.500000
#
# [183 rows x 2 columns]

# %% [markdown]
# ## 6. Group By `Occupation` and `Gender` Columns, then Calculate Average Salary and Age

# %%
# Group by Occupation and Gender columns

group_df = people_df.groupby(["Occupation", "Gender"]).mean()
group_df
# Out:
#                                         Salary        Age
# Occupation               Gender
# Account Coordinator      Female   98514.000000  47.500000
#                          Male     88030.500000  55.250000
# Account Executive        Female   82720.666667  52.666667
#                          Male     71449.000000  33.000000
# Account Representative I Male     75871.000000  63.000000
# ...                                        ...        ...
# Web Developer II         Male     75447.000000  58.000000
# Web Developer III        Female  101919.000000  41.000000
#                          Male     79562.500000  41.500000
# Web Developer IV         Female   76349.000000  42.500000
#                          Male     77281.500000  26.500000
#
# [315 rows x 2 columns]

# %%
group_df[['Salary']].sample(50).plot(kind="bar", figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Occupation,Gender'>
